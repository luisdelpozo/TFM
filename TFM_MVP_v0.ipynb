# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/home/dsc/Documents/TFM/Data/OMIE/PALOS1_21-27_sept_2020.csv')

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  WEEKDAY  HOUR  €/MW h   MW h
# 0  2020      9   21        1     1   180.3  394.1
# 1  2020      9   21        1     2   180.3  394.1
# 2  2020      9   21        1     3   180.3  394.1
# 3  2020      9   21        1     4   180.3  319.1
# 4  2020      9   21        1     5   180.3  274.1

# %%
df.shape
# Out:
# (168, 7)

# %%
df.tail()
# Out:
#      YEAR  MONTH  DAY  WEEKDAY  HOUR  €/MW h  MW h
# 163  2020      9   27        7    20   180.3  34.1
# 164  2020      9   27        7    21   180.3  34.1
# 165  2020      9   27        7    22   180.3  34.1
# 166  2020      9   27        7    23   180.3  34.1
# 167  2020      9   27        7    24   180.3  34.1

# %%
len(df)
# Out:
# 168

# %%
xs = np.linspace(0, len(df), len(df))

# %%
df.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'WEEKDAY', 'HOUR', '€/MW h', 'MW h'], dtype='object')

# %%
plt.plot(xs, df['MW h'])

# %%
sns.lineplot(data=df['MW h'])
# Out:
# <AxesSubplot:ylabel='MW h'>

# %%
sns.set_theme(style='darkgrid')

sns.lineplot(data=df['MW h'])
# Out:
# <AxesSubplot:ylabel='MW h'>

# %%
sns.lineplot(data=df['€/MW h'])
# Out:
# <AxesSubplot:ylabel='€/MW h'>

# %%
df.columns = ['YEAR', 'MONTH', 'DAY', 'WEEKDAY', 'HOUR', 'PRICE', 'ENERGY']

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  WEEKDAY  HOUR  PRICE  ENERGY
# 0  2020      9   21        1     1  180.3   394.1
# 1  2020      9   21        1     2  180.3   394.1
# 2  2020      9   21        1     3  180.3   394.1
# 3  2020      9   21        1     4  180.3   319.1
# 4  2020      9   21        1     5  180.3   274.1

# %%
df_det = pd.read_csv('/home/dsc/Documents/TFM/Data/OMIE/PALOS1_21-27_sept_2020_det.csv')

# %%
df_det.head()
# Out:
#    NUM. OFF.  NUM. VERS.  PERIODO  BLOQUE  EMPTY  € / MW h   MW h DIV. RETIR.
# 0    6496963           1        1      12      0    180.30  394.1    S      S
# 1    6496963           1        2      12      0    180.30  394.1    S      S
# 2    6496963           1        3      12      0    180.30  394.1    S      S
# 3    6496963           1        4       1      0      1.13   75.0    S      S
# 4    6496963           1        4      12      0    180.30  319.1    S      S

# %%
sns.lineplot(data=df_det['MW h'])
# Out:
# <AxesSubplot:ylabel='MW h'>

# %%
sns.lineplot(data=df_det['€ / MW h'])
# Out:
# <AxesSubplot:ylabel='€ / MW h'>

# %%
df_det['NUM. OFF.'].value_counts()
# Out:
# 6498034    199
# 6503904    199
# 6505575    199
# 6499408    199
# 6496963    199
# 6500842    199
# 6502429    199
# Name: NUM. OFF., dtype: int64

# %%
df_det_monday = df_det[df_det['NUM. OFF.'] == 6498034]

# %%
df_det_monday.shape
# Out:
# (199, 9)

# %%
sns.lineplot(data=df_det_monday['MW h'])
# Out:
# <AxesSubplot:ylabel='MW h'>

# %%
sns.lineplot(data=df_det_monday['€ / MW h'])
# Out:
# <AxesSubplot:ylabel='€ / MW h'>
